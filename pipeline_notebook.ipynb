# %%
# %matplotlib inline

# %%
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib.gridspec import GridSpec, GridSpecFromSubplotSpec
from matplotlib.lines import Line2D
from matplotlib import colors
import jax.experimental.sparse as jsparse
from scipy import sparse
from matplotlib.lines import Line2D
from scipy.optimize import fsolve
from matplotlib.patches import Rectangle
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import networkx as nx
from scipy.interpolate import griddata
from scipy.integrate import odeint
from scipy.interpolate import CubicSpline

from innov.simple_calculations import *
from innov.automaton import *
from innov.tree_gen import *
from innov import plot

imgdr = os.path.expanduser('~/Dropbox/Research/innov2/writing/20230917_draft')
assert os.path.isdir(imgdr)

# %%
plt.rc('font', size=20)
np.set_printoptions(precision=4, linewidth=1200)

# %% [markdown]
# # Figure 1: Raw and pseudogap density representations

# %%
# choose plotting parameters
Lplot = 100
t_ix = -1

fig, axs = plt.subplots(ncols=3, nrows=2, figsize=(7,5),
                        sharey=True,
                        gridspec_kw={'hspace':.55, 'wspace':.25})
plot.examples(axs, Lplot, t_ix)

# plotting cleanup
axs[0,0].set_ylabel(r"density $n(x')$", fontsize='small')
axs[0,1].set_xlabel(r"generation $x'$", fontsize='small')
axs[1,0].set_ylabel(r'density $n(x)$', fontsize='small')
axs[1,1].set_xlabel(r'distance from inn. front $x$', fontsize='small')

axs[0,0].set(xlim=(0, 100), ylim=(0, 30))
[a.set(xlim=(0, Lplot)) for a in axs[0]]
[a.set(xlim=(0, 100)) for a in axs[1]]
for a in axs.ravel():
    [el.set_fontsize('small') for el in a.xaxis.get_ticklabels()]
    [el.set_fontsize('small') for el in a.yaxis.get_ticklabels()]

axs[0,0].text(97, 24, '(b)', ha='right')
axs[0,1].text(97, 24, '(c)', ha='right')
axs[0,2].text(97, 24, '(d)', ha='right')
axs[1,0].text(97, 24, '(e)', ha='right')
axs[1,1].text(97, 24, '(f)', ha='right')
axs[1,2].text(97, 24, '(g)', ha='right')

fig.savefig(f"{imgdr}/fig1_top.png", bbox_inches='tight', dpi=200)

# %% [markdown]
# # Figure 2

# %%
fig = plt.figure(figsize=(11.5,3))
gs = GridSpec(3, 3, wspace=.48, hspace=.3)
ax = [fig.add_subplot(gs[0,0]), fig.add_subplot(gs[1,0]), fig.add_subplot(gs[2,0]),
      fig.add_subplot(gs[:,1]), fig.add_subplot(gs[:,2])]

plot.front_test([ax[0], ax[3], ax[4]], 'cache/front_vel_test_0.p', c='C0')
plot.front_test([ax[1], ax[3], ax[4]], 'cache/front_vel_test_1.p', c='C1')
plot.front_test([ax[2], ax[3], ax[4]], 'cache/front_vel_test_2.p', c='C2')

ax[0].set(xticklabels=[], ylim=(-1, 11), yticks=[0,5,10], xlim=(-.05, 1.05))
ax[1].set(xticklabels=[], ylim=(-1, 11), yticks=[0,5,10], xlim=(-.05, 1.05), ylabel=r'mean $\lambda$')
ax[2].set(ylim=(-1, 11), yticks=[0,5,10], xlim=(-.05, 1.05),
          xlabel=r'connectivity $\gamma$')
ax[3].set(xlabel=r'connectivity $\gamma$', ylabel=r'inn. front vel. $n(0)r\tilde I$',
          ylim=(0,10), yticks=[0, 5, 10])
ax[4].set(xlabel=r'connectivity $\gamma$', ylabel=r'ex. front vel. $\tilde v_o$',
          ylim=(0,10), yticks=[0, 5, 10])

# legends
ax[2].legend(ax[2].get_lines(), ('inn.', 'ex.', 'pred.'), fontsize='xx-small',
             columnspacing=.1, handletextpad=.0, loc='upper center', borderpad=.15, framealpha=1, labelspacing=.1)
ax[3].legend(ax[3].get_lines(), ('sim.', 'pred.'), fontsize='xx-small', loc=4)
ax[4].legend(ax[4].get_lines()[::2], (r'$K=25$', r'$K=50$', r'$K=100$'), fontsize='xx-small', loc=4, labelspacing=.1, borderpad=.15)

fig.text(.317, .786, '(a)', ha='right')
fig.text(.317, .505, '(b)', ha='right')
fig.text(.317, .235, '(c)', ha='right')
fig.text(.607, .786, '(d)', ha='right')
fig.text(.896, .786, '(e)', ha='right')

fig.savefig(f'{imgdr}/mft_velocity.pdf', bbox_inches='tight')

# %% [markdown]
# # Figure 3: Phase space

# %%
fig = plt.figure(figsize=(9.5,4))
gridspec = GridSpec(2, 2, hspace=.25, wspace=.3)
ax = (fig.add_subplot(gridspec[:,0]),
      fig.add_subplot(gridspec[0,1]),
      fig.add_subplot(gridspec[1,1]))

plot.dynamical_phase_space(ax[0])

r0 = 10
I = 2
rd = .5

r = .4
plot.structure_phase_space(r0/r, I, rd/r, ax[1], low_density=True)
ax[1].legend(fontsize='x-small', handlelength=1.14, loc=1)
ax[1].text(1.02, 1, '(b)', fontsize=24, transform=ax[1].transAxes, va='top')
ax[1].set(xticklabels=[])

r = .52
plot.structure_phase_space(r0/r, I, rd/r, ax[2], runaway=True)
ax[2].set(ylabel='', xlabel=r'branch number $K$')
ax[2].text(1.02, 1, '(c)', fontsize=24, transform=ax[2].transAxes, va='top')

fig.savefig(f'{imgdr}/phase_space_top.png', dpi=200, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(9.5+.2375, 4))
gridspec = GridSpec(1, 3, wspace=.07, width_ratios=(1,1,.05))
gs = GridSpecFromSubplotSpec(2, 2, gridspec[:2], wspace=.3)
ax = (fig.add_subplot(gs[:,0]),
      fig.add_subplot(gs[0,1]),
      fig.add_subplot(gs[1,1]),
      fig.add_subplot(gridspec[0,2]))

plot.dynamics_density(fig, ax[0], n_points=401)

plot.structure_density(fig, ax[1], ax[3], n_points=400)
ax[1].set(xticklabels=[])
ax[1].set(ylabel=r'connectivity $\gamma$                     ', xticks=[1, 50,100], yticks=[0,1])
ax[2].set(xlabel=r'branch number $K$')

plot.structure_density(fig, ax[2], ax[3], r=.52, n_points=800)
K_critical, gamma_range = plot.critical_K_line()
ax[2].fill_betweenx(gamma_range, np.zeros_like(gamma_range), K_critical, lw=0, fc='gray')
ax[2].fill_between(K_critical[gamma_range<.5], gamma_range[gamma_range<.5], np.zeros((gamma_range<.5).sum()),
                   fc='gray', lw=0, ec='gray')
ax[2].fill_between([1, 10], [.05, .05], fc='gray')
ax[2].set(xlim=(1, 100), ylim=(0,1), yticks=[0,1])

ax[0].text(2.7, 2.65, '(d)', fontsize=24, ha='center')
ax[1].text(91, .75, '(e)', fontsize=24, ha='center')
ax[2].text(91, .75, '(f)', fontsize=24, ha='center')

fig.savefig(f'{imgdr}/NminusL.png', bbox_inches='tight', dpi=200)
# Out:
# /home/eddie/Dropbox/Research/innov2/py/innov/simple_calculations.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   quadform = (B + sqrt(C)) / (2 * A)
# /home/eddie/Dropbox/Research/innov2/py/innov/simple_calculations.py:162: RuntimeWarning: divide by zero encountered in scalar divide
#   quadform = (B + sqrt(C)) / (2 * A)
# /home/eddie/Dropbox/Research/innov2/py/innov/plot.py:426: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([0,1,2,3], fontsize='small')

# %%
r0 = 100
I =  .2
rd =  0.9
vo =  .7
gamma = .1
K = 50
tmax = 150

model = CompartmentModel(r0, I, rd, vo, gamma, K)
linestyles = '-', '-.', '--'

fig, ax = plt.subplots(figsize=(9.5, 4), ncols=2, gridspec_kw={'wspace':.3},
                       sharex=True, sharey=True)
y0 = np.array([model.N()[0], model.L()[0], model.n0(), model.nl()[0]]).real

for i, dL in enumerate([0, -1, 1]):     # rest of dynamic parameters: rate of death, rate of obsolescence   
    y0_ = y0.copy()
    y0_[1] += dL
    t = np.linspace(0, tmax, int(1e4)*2)
    y = odeint(pde_pseudogap, y0_, t, args=(r0, I, rd, vo, gamma, K))
    
    ax[0].plot(t, y[:,0], linestyles[i], c='C0')
    ax[0].plot(t, y[:,1], linestyles[i], c='C1')
    ax[1].plot(t, y[:,2], linestyles[i], c='C2')
    ax[1].plot(t, y[:,3], linestyles[i], c='C3')

ax[0].set(xlabel=r'time $t$', yscale='log', xlim=(0, tmax), ylim=[1, 1e5])
ax[0].set_ylabel(r'', rotation='horizontal')
ax[0].legend((r'$N(t)$', r'$L(t)$'), fontsize='x-small', loc=3)
ax[1].set(xlabel=r'time $t$', yscale='log', xlim=(0, tmax))
ax[1].legend((r'$n(x=0,t)$', r'$n(x=L-1,t)$'), fontsize='x-small')

fig.text(.04, .8, '(g)', fontsize=24)
fig.text(.92, .8, '(h)', fontsize=24)

fig.savefig(f'{imgdr}/bifurcation.png', bbox_inches='tight', dpi=200)

# %% [markdown]
# # Figure 4

# %%
# Interpolate results
n_points = 50

# Plot the heat map
fig = plt.figure(figsize=(8,3))
gs = GridSpec(2, 2, width_ratios=(1,1.05), figure=fig)
gs_sub = GridSpecFromSubplotSpec(2, 2, gs[:,1], width_ratios=(1, .05))
ax = fig.add_subplot(gs[:,0]), fig.add_subplot(gs_sub[0,0]), fig.add_subplot(gs_sub[1,0])
colorbarax = fig.add_subplot(gs_sub[:,1])

# dynamical phase diagram ================================================================
cax = plot.dynamics_survival_phase_diagram('cache/dynamics_survival_grid.p', ax[0])
ax[0].set(xlabel=r'ex. velocity $v_o$', ylabel=r'death rate $r_d$')

# structural phase diagram ===============================================================
K_grid, gamma_grid, f_rep, f_branch = plot.load_survival_grid('structure_survival_grid_stable.p')
K_range = K_grid[0]
gamma_range = gamma_grid[:,0]
Ki, gammai = np.meshgrid(np.linspace(K_range[0], K_range[-1], n_points), np.linspace(0, 1, n_points))
fi = griddata((K_grid.ravel(), gamma_grid.ravel()), f_branch.flatten(), (Ki.ravel(), gammai.ravel()),
              method='linear', fill_value=1.)
fi = fi.reshape(n_points, n_points)
cax = ax[1].imshow(fi, extent=(Ki.min(), Ki.max(), gammai.min(), gammai.max()),
                   origin='lower', aspect='auto', cmap='Reds', vmin=0, vmax=1)
plot.structure_phase_space_stable(ax[1])
ax[1].set(yticks=[0,1], xticklabels=[], xlim=(1, 100))
[el.set_fontsize('small') for el in ax[1].yaxis.get_ticklabels()]

K_grid, gamma_grid, f_rep, f_branch = plot.load_survival_grid('structure_survival_grid_runaway.p')
K_range = K_grid[0]
gamma_range = gamma_grid[:,0]
Ki, gammai = np.meshgrid(np.linspace(K_range[0], K_range[-1], n_points), np.linspace(0, 1, n_points))
fi = griddata((K_grid.ravel(), gamma_grid.ravel()), f_branch.flatten(), (Ki.ravel(), gammai.ravel()),
              method='linear', fill_value=1.)
fi = fi.reshape(n_points, n_points)
cax = ax[2].imshow(fi, extent=(Ki.min(), Ki.max(), gammai.min(), gammai.max()),
                   origin='lower', aspect='auto', cmap='Reds', vmin=0, vmax=1)
plot.structure_phase_space_runaway(ax[2])
ax[2].set(xlim=(1, 100), yticks=[0,1])
[el.set_fontsize('small') for el in ax[1].yaxis.get_ticklabels()]

ax[2].set(xlabel=r'branching number $K$', yticks=[0,1])
[el.set_fontsize('small') for el in ax[2].yaxis.get_ticklabels()]
[el.set_fontsize('small') for el in ax[2].xaxis.get_ticklabels()]

fig.colorbar(cax, cax=colorbarax, ticks=[0,.5,1], label='fraction surviving')

fig.text(.465, .78, '(a)', ha='right')
fig.text(.85, .78, '(b)', ha='right')
fig.text(.85, .3652, '(c)', ha='right')

fig.savefig(f'{imgdr}/stochastic_phase_diagram.pdf', bbox_inches='tight')
